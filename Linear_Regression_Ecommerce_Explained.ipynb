# %%
# Importing necessary libraries 📚
import numpy as np
# Importing necessary libraries 📚
import pandas as pd
# Importing necessary libraries 📚
import matplotlib.pyplot as plt
# Importing necessary libraries 📚
import seaborn as sns

# %%
# Reading the dataset (CSV file) into a DataFrame
df=pd.read_csv("Ecommerce_Customers")
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
# Displaying the first few rows of the dataset
df.head(10)
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
# 5         alvareznancy@lucas.biz
# 6          katherine20@yahoo.com
# 7             awatkins@yahoo.com
# 8    vchurch@walter-martinez.com
# 9               bonnie69@lin.biz
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# 5  645 Martha Park Apt. 611\nJeffreychester, MN 6...       FloralWhite
# 6  68388 Reyes Lights Suite 692\nJosephbury, WV 9...     DarkSlateBlue
# ...

# %%
df.tail(10)
# Out:
#                             Email  \
# 490           brian28@sanchez.org
# 491    leonardhancock@hotmail.com
# 492    davidsonkathleen@gmail.com
# 493           nathan84@lowery.net
# 494         kellydeborah@chan.biz
# 495  lewisjessica@craig-evans.com
# 496           katrina56@gmail.com
# 497            dale88@hotmail.com
# 498           cwilson@hotmail.com
# 499     hannahwilson@davidson.com
#
#                                                Address          Avatar  \
# 490    7446 Mary Ferry\nLake Sherryfurt, GA 49066-0207      GhostWhite
# 491  64147 Alexander Station Apt. 474\nEast Jasonvi...        SeaShell
# 492   70128 Zimmerman Overpass\nRobertsshire, VA 59860        DarkBlue
# 493  01242 Stephanie Ways Suite 003\nChurchville, M...  MediumSeaGreen
# 494    354 Sanchez Wall Suite 884\nJuliabury, VI 39735   DarkTurquoise
# 495  4483 Jones Motorway Suite 872\nLake Jamiefurt,...             Tan
# 496  172 Owen Divide Suite 497\nWest Richard, CA 19320   PaleVioletRed
# ...

# %%
df.sample(10)
# Out:
#                               Email  \
# 94             raylopez@hotmail.com
# 239           hornesteven@gmail.com
# 463        salazarkaren@hotmail.com
# 432         katherinegray@yahoo.com
# 300         johnsonhannah@gmail.com
# 428             kevin45@mathews.net
# 410       jenniferjenkins@jones.com
# 334      jonathanconner@morales.biz
# 131            kristina69@gmail.com
# 212  baldwinbryan@estrada-silva.biz
#
#                                                Address          Avatar  \
# 94   3600 Amber Plains Suite 002\nNorth Jamesburgh,...   DarkGoldenRod
# 239           91425 Roy Trail\nRivaston, NE 34949-2588           White
# 463  51173 Burton Wall Apt. 417\nPrestonville, NY 3...       SteelBlue
# 432  685 Sexton Ranch Suite 125\nLake Robertshire, ...            Cyan
# 300        634 Robert Hill Apt. 800\nCoxtown, OK 32430         Thistle
# 428   02393 Baker Falls\nNew Georgeport, ND 36338-5110      DodgerBlue
# ...

# %%
df.isnull().sum()
# Out:
# Email                   0
# Address                 0
# Avatar                  0
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in df.select_dtypes(include='number').columns:
  plt.figure(figsize=(6,4))
  sns.histplot(data=df,x=col)
# Adding a title to the plot
  plt.title(f'Distribution of {col}')

# %%
# Pairplot: visualize pairwise relationships between numeric variables
sns.pairplot(df,
             kind='scatter',
             plot_kws={'alpha':0.4},
             diag_kws={'alpha':0.55, 'bins':40})

# %%
# Heatmap of correlation matrix to see how strongly features are related
sns.heatmap(df.select_dtypes(include='number').corr(),annot=True,fmt=".2f",cmap="Blues")
# Out:
# <Axes: >

# %%
sns.lmplot(x='Length of Membership',y='Yearly Amount Spent',data=df,scatter_kws={'alpha':0.3})

# %%
# Splitting the dataset into training and testing sets
from sklearn.model_selection import train_test_split

# %%
# General info about the dataset (columns, types, nulls, etc.)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
X=df[['Avg. Session Length','Time on App','Time on Website','Length of Membership']]
y=df['Yearly Amount Spent']

# %%
# Splitting the dataset into training and testing sets
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
# Importing Linear Regression model from sklearn
from sklearn.linear_model import LinearRegression

# %%
# Importing Linear Regression model from sklearn
lm = LinearRegression()

# %%
# Fitting the linear model on training data
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([25.72425621, 38.59713548,  0.45914788, 61.67473243])

# %%
# Making predictions using the trained model
pred=lm.predict(X_test)

# %%
# Plotting scatter plot to visualize relationship between features and target
sns.scatterplot(x=y_test,y=pred)
# Label for y-axis
plt.ylabel("Predictions")
# Adding a title to the plot
plt.title("Actual vs Predictions")
# Out:
# Text(0.5, 1.0, 'Actual vs Predictions')

# %%
# Calculating Mean Squared Error for evaluation
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %%
print('Mean Absolute Error:',mean_absolute_error(y_test, pred))
# Calculating Mean Squared Error for evaluation
print('Mean Squared Error:',mean_squared_error(y_test, pred))
# Calculating Mean Squared Error for evaluation
print('Root Mean Squared Error:',math.sqrt(mean_squared_error(y_test, pred)))
# Out:
# Mean Absolute Error: 8.426091641432116
# Mean Squared Error: 103.91554136503333
# Root Mean Squared Error: 10.193897260863155

# %%
residuals=y_test-pred

# %%
sns.displot(residuals,bins=30,kde=True)
